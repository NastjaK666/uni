# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")
url = 'https://raw.githubusercontent.com/NastjaK666/uni/dcd6ad5f9b1995424b4e7fd5d20e81c82ce0626a/top2018.csv'
data = pd.read_csv(url)
# Dataset is now stored in a Pandas Dataframe
import altair as alt

# %%
data.head()
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
data.shape
# Out:
# (100, 16)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 100

# %%
data.columns
# Out:
# Index([u'id', u'name', u'artists', u'danceability', u'energy', u'key',
#        u'loudness', u'mode', u'speechiness', u'acousticness',
#        u'instrumentalness', u'liveness', u'valence', u'tempo', u'duration_ms',
#        u'time_signature'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                   object
# name                 object
# artists              object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# time_signature      float64
# dtype: object

# %%
for col in data.columns:
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# id - 0
# name - 0
# artists - 0
# danceability - 0
# energy - 0
# key - 0
# loudness - 0
# mode - 0
# speechiness - 0
# acousticness - 0
# instrumentalness - 0
# liveness - 0
# valence - 0
# tempo - 0
# duration_ms - 0
# time_signature - 0

# %%
data.describe() 
# count - number of entries
# mean - average (sum/count)
# std - standard deviation (sum(value-mean)^2)^1/2
# min - minimal value
# max - maximal value
# Out:
#        danceability      energy  ...    duration_ms  time_signature
# count     100.00000  100.000000  ...     100.000000          100.00
# mean        0.71646    0.659060  ...  205206.780000            3.98
# std         0.13107    0.145067  ...   40007.893404            0.20
# min         0.25800    0.296000  ...   95467.000000            3.00
# 25%         0.63550    0.562000  ...  184680.000000            4.00
# 50%         0.73300    0.678000  ...  205047.500000            4.00
# 75%         0.79825    0.772250  ...  221493.250000            4.00
# max         0.96400    0.909000  ...  417920.000000            5.00
#
# [8 rows x 13 columns]

# %%
data['key'].unique()
# Out:
# array([ 7.,  8.,  5.,  1., 10.,  9.,  2.,  6.,  0., 11.,  4.,  3.])

# %%
data['artists'].unique()
# Out:
# array(['Drake', 'XXXTENTACION', 'Post Malone', 'Cardi B', 'Calvin Harris',
#        'Dua Lipa', 'Marshmello', 'Camila Cabello', 'Juice WRLD',
#        'Maroon 5', 'Zedd', 'Kendrick Lamar', 'Ariana Grande', 'Nicky Jam',
#        'BlocBoy JB', 'Rudimental', 'Nio Garcia', 'Bazzi',
#        '5 Seconds of Summer', 'Ed Sheeran', 'Khalid', 'Bebe Rexha',
#        'Tyga', 'Clean Bandit', 'Dennis Lloyd', 'Luis Fonsi',
#        'benny blanco', 'Selena Gomez', 'Dynoro', 'Eminem', 'Daddy Yankee',
#        'Travis Scott', 'Imagine Dragons', 'Reik', 'Ti?sto', 'Bruno Mars',
#        'NF', 'The Weeknd', 'Offset', 'Sam Smith', 'Lil Dicky', '6ix9ine',
#        'Jonas Blue', 'Loud Luxury', 'Lil Uzi Vert', 'Becky G',
#        'Anne-Marie', 'Shawn Mendes', 'Piso 21', 'David Guetta',
#        'DJ Snake', 'Hailee Steinfeld', 'Portugal. The Man', 'Migos',
#        'G-Eazy', 'Sofia Reyes', 'Natti Natasha', 'Rich The Kid',
#        'Billie Eilish', 'Ozuna', 'Maluma', 'Anitta', 'Wolfine',
# ...

# %%
alt.Chart(data).mark_point().encode(
    x='energy',
    y='loudness',
    color='key',
).interactive()
# Out:
# Chart({
#   data:                        id  ... time_signature
#   0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
#   1   3ee8Jmje8o58CHK66QrVC  ...            4.0
#   2   0e7ipj03S05BNilyu5bRz  ...            4.0
#   3   3swc6WTsr7rl9DqQKQA55  ...            4.0
#   4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#   5   7dt6x5M1jzdTEt8oCbisT  ...            4.0
#   6   58q2HKrzhC3ozto2nDdN4  ...            4.0
#   7   7ef4DlsgrMEH11cDZd32M  ...            4.0
#   8   76cy1WJvNGJTj78UqeA5z  ...            4.0
#   9   08bNPGLD8AhKpnnERrAc6  ...            4.0
#   10  1rfofaqEpACxVEHIZBJe6  ...            4.0
#   11  0s3nnoMeVWz3989MkNQiR  ...            4.0
#   12  3CA9pLiwRIGtUBiMjbZmR  ...            4.0
#   13  7fa9MBXhVfQ8P8Df9OEbD  ...            4.0
#   14  09IStsImFySgyp0pIQdqA  ...            4.0
#   15  3GCdLUSnKSMJhs4Tj6CV3  ...            4.0
#   16  2qT1uLXPVPzGgFOx4jtEu  ...            4.0
#   17  39N9RPD9MRb5WmoLzNzPe  ...            4.0
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['valence'])

# %%
sns.jointplot(x='energy', y='danceability', data=data)

# %%
sns.jointplot(x='energy', y='danceability', data=data, kind = "hex")

# %%
alt.Chart(data).mark_point().encode(
    x='tempo',
    y='valence',
    color='mode',
).interactive()
# Out:
# Chart({
#   data:                        id  ... time_signature
#   0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
#   1   3ee8Jmje8o58CHK66QrVC  ...            4.0
#   2   0e7ipj03S05BNilyu5bRz  ...            4.0
#   3   3swc6WTsr7rl9DqQKQA55  ...            4.0
#   4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#   5   7dt6x5M1jzdTEt8oCbisT  ...            4.0
#   6   58q2HKrzhC3ozto2nDdN4  ...            4.0
#   7   7ef4DlsgrMEH11cDZd32M  ...            4.0
#   8   76cy1WJvNGJTj78UqeA5z  ...            4.0
#   9   08bNPGLD8AhKpnnERrAc6  ...            4.0
#   10  1rfofaqEpACxVEHIZBJe6  ...            4.0
#   11  0s3nnoMeVWz3989MkNQiR  ...            4.0
#   12  3CA9pLiwRIGtUBiMjbZmR  ...            4.0
#   13  7fa9MBXhVfQ8P8Df9OEbD  ...            4.0
#   14  09IStsImFySgyp0pIQdqA  ...            4.0
#   15  3GCdLUSnKSMJhs4Tj6CV3  ...            4.0
#   16  2qT1uLXPVPzGgFOx4jtEu  ...            4.0
#   17  39N9RPD9MRb5WmoLzNzPe  ...            4.0
# ...

# %%
sns.jointplot(x='tempo', y='valence', data=data, kind = "kde")

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="danceability")
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python2.7/dist-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python2.7/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
data.corr()
# Out:
#                   danceability    energy  ...  duration_ms  time_signature
# danceability          1.000000 -0.072582  ...    -0.068368        0.119421
# energy               -0.072582  1.000000  ...     0.073017        0.255235
# key                  -0.051759 -0.136345  ...     0.046144       -0.087096
# loudness              0.015517  0.732719  ...     0.265310        0.072301
# mode                 -0.058019 -0.117555  ...     0.055411       -0.083782
# speechiness           0.227075 -0.073591  ...    -0.009856        0.235615
# acousticness         -0.134374 -0.421209  ...    -0.069627       -0.158935
# instrumentalness     -0.066592  0.093684  ...    -0.045873        0.011894
# liveness             -0.038761  0.050542  ...    -0.042942       -0.079558
# valence               0.413855  0.382434  ...    -0.131901        0.223410
# tempo                -0.195012  0.062272  ...     0.005493        0.090191
# ...

# %%
data.corr(method='pearson')
# Out:
#                   danceability    energy  ...  duration_ms  time_signature
# danceability          1.000000 -0.072582  ...    -0.068368        0.119421
# energy               -0.072582  1.000000  ...     0.073017        0.255235
# key                  -0.051759 -0.136345  ...     0.046144       -0.087096
# loudness              0.015517  0.732719  ...     0.265310        0.072301
# mode                 -0.058019 -0.117555  ...     0.055411       -0.083782
# speechiness           0.227075 -0.073591  ...    -0.009856        0.235615
# acousticness         -0.134374 -0.421209  ...    -0.069627       -0.158935
# instrumentalness     -0.066592  0.093684  ...    -0.045873        0.011894
# liveness             -0.038761  0.050542  ...    -0.042942       -0.079558
# valence               0.413855  0.382434  ...    -0.131901        0.223410
# tempo                -0.195012  0.062272  ...     0.005493        0.090191
# ...

# %%
data.corr(method='kendall')
# Out:
#                   danceability    energy  ...  duration_ms  time_signature
# danceability          1.000000 -0.111246  ...    -0.071782        0.107028
# energy               -0.111246  1.000000  ...    -0.023644        0.179959
# key                  -0.039328 -0.092132  ...    -0.020491       -0.075551
# loudness              0.002427  0.502829  ...     0.093949        0.075871
# mode                 -0.091403 -0.104645  ...     0.046527       -0.084750
# speechiness           0.234045  0.008693  ...    -0.022231        0.268158
# acousticness         -0.111651 -0.183950  ...     0.003031       -0.126477
# instrumentalness      0.133539 -0.074406  ...    -0.141446        0.081074
# liveness             -0.089353 -0.005872  ...     0.007692       -0.091220
# valence               0.241198  0.287159  ...    -0.079854        0.182924
# tempo                -0.058033  0.003840  ...     0.021414        0.078753
# ...

# %%
data.corr(method='spearman')
# Out:
#                   danceability    energy  ...  duration_ms  time_signature
# danceability          1.000000 -0.157108  ...    -0.111933        0.130160
# energy               -0.157108  1.000000  ...    -0.028875        0.219800
# key                  -0.063513 -0.137498  ...    -0.030338       -0.088967
# loudness             -0.012434  0.684884  ...     0.141117        0.093841
# mode                 -0.111292 -0.127490  ...     0.056701       -0.085067
# speechiness           0.337911  0.010642  ...    -0.045863        0.325627
# acousticness         -0.160525 -0.270338  ...     0.011479       -0.155372
# instrumentalness      0.171022 -0.095219  ...    -0.198837        0.091520
# liveness             -0.140176  0.007438  ...     0.004507       -0.111763
# valence               0.344770  0.415092  ...    -0.122361        0.223126
# tempo                -0.095148 -0.001326  ...     0.031647        0.097235
# ...

# %%
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(20,10))
sns.heatmap(data.corr(method='pearson'), ax=ax[0], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='kendall'), ax=ax[1], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='spearman'), ax=ax[2], annot=True, fmt='.2f')
fig.suptitle(u'Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
